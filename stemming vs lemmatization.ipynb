# %% [markdown]
# ### **Hagar Sherif Hassan **

# %% [markdown]
# # Check for the quality of stemming of NLTK vs lemmatization of spacy

# %% [markdown]
# **1. Stemming of NLTK**

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import pandas as pd 

ps = PorterStemmer()

text = """Nikola Tesla was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist best known for his contributions to the design of the modern alternating current electricity supply system.""" 
tokens = word_tokenize(text)

stemmed = []

for item in tokens:
     stemmed_word = ps.stem(item)
     stemmed.append(stemmed_word)

df = pd.DataFrame(data={"tokens":tokens, "stemmed": stemmed})  
df
# Out:
#               tokens           stemmed
# 0             Nikola            nikola
# 1              Tesla             tesla
# 2                was                wa
# 3                  a                 a
# 4   Serbian-American  serbian-american
# 5           inventor          inventor
# 6                  ,                 ,
# 7         electrical            electr
# 8           engineer             engin
# 9                  ,                 ,
# 10        mechanical            mechan
# 11          engineer             engin
# 12                 ,                 ,
# 13               and               and
# 14          futurist          futurist
# 15              best              best
# 16             known             known
# 17               for               for
# 18               his                hi
# 19     contributions         contribut
# 20                to                to
# 21               the               the
# 22            design            design
# ...

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
  
group = ["Read", "Reading", "Reader", "Readers","Friends", "Friendship", "Friendly"]
  
for i in group:
    print(i, " --> ", ps.stem(i))
# Out:
# Read  -->  read
# Reading  -->  read
# Reader  -->  reader
# Readers  -->  reader
# Friends  -->  friend
# Friendship  -->  friendship
# Friendly  -->  friendli

# %% [markdown]
# **2. Lemmatization of spacy**

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = nlp("Nikola Tesla was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist best known for his contributions to the design of the modern alternating current electricity supply system." )
list1 = []
for item in text:
  list1.append(item.lemma_)

final_text = ' '.join(map(str,list1))
print(final_text)
# Out:
# Nikola Tesla be a serbian - american inventor , electrical engineer , mechanical engineer , and futurist well know for his contribution to the design of the modern alternate current electricity supply system .

# %% [markdown]
# **Conclusion:**
#
# *  Stemming reduces the word to its stem by removing all affixes.
# *  Lemmatization reduces the word to its root.
